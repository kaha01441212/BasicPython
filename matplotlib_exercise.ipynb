# %% [markdown]
# # 【確認課題】Matplotlib

# %%
# 使うライブラリ
# !pip install japanize-matplotlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import japanize_matplotlib
japanize_matplotlib.japanize()

# %% [markdown]
# ## 1問目
# 使うcsvはhist_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問1](./imgs/matplotlib/plot_1.png)

# %%
df = pd.read_csv('data/hist_data.csv')
plt.hist(df['aデータ'], bins = 30 ,color=(1, 0, 0, 0.5))
plt.hist(df['bデータ'], bins = 30 ,color=(0/255, 191/255, 255/255, 0.5))
# Out:
# (array([ 1.,  7.,  5.,  6.,  9., 17., 12., 17., 17., 25., 26., 27., 24.,
#          6.,  8.,  7.,  5.,  5.,  6.,  2.,  5.,  2.,  1.,  0.,  1.,  3.,
#          1.,  1.,  1.,  6.]),
#  array([ 5.6 ,  7.08,  8.56, 10.04, 11.52, 13.  , 14.48, 15.96, 17.44,
#         18.92, 20.4 , 21.88, 23.36, 24.84, 26.32, 27.8 , 29.28, 30.76,
#         32.24, 33.72, 35.2 , 36.68, 38.16, 39.64, 41.12, 42.6 , 44.08,
#         45.56, 47.04, 48.52, 50.  ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## 2問目
# 使うcsvはscatter_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問2](./imgs/matplotlib/plot_2.png)

# %%
df = pd.read_csv('data/scatter_data.csv')

df_class_0 = df[df['class'] == 0]
df_class_1 = df[df['class'] == 1]
df_class_2 = df[df['class'] == 2]

plt.scatter(df_class_0['length (cm)'], df_class_0['width (cm)'] ,color = 'red' ,label='Class0')
plt.scatter(df_class_1['length (cm)'], df_class_1['width (cm)'] ,color = 'blue' ,label='Class1')
plt.scatter(df_class_2['length (cm)'], df_class_2['width (cm)'] ,color = 'green' ,label='Class2')

plt.xlabel('Length (cm)')
plt.ylabel('Width (cm)')
plt.title('クラス0~2のlengthとwidchに関する散布図')

plt.grid()
plt.show()

# %% [markdown]
# ## 3問目
# 使うcsvはline_data.csvです。下に2つの画像を表示するコードを書いてください。

# %% [markdown]
# ![問3_1](./imgs/matplotlib/plot_3_1.png)

# %% [markdown]
# ![問3_2](./imgs/matplotlib/plot_3_2.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSVファイルからデータを読み込む
df = pd.read_csv('data/line_data.csv')

# サブプロットを作成
plt.figure(figsize=(7, 8))

# 折れ線グラフのサブプロットを追加
plt.subplot(2, 1, 1)
plt.plot(df['期間'], df['件数'], marker="o")
plt.ylabel('楕円(円)')
plt.title('期間ごとの費用の推移')
plt.xticks(rotation=30)
plt.grid()

# 棒グラフのサブプロットを追加
plt.subplot(2, 1, 2)
plt.bar(df['期間'], df['件数'])
plt.ylabel('楕円(円)')
plt.xlabel('期間')
plt.xticks(rotation=30)
plt.grid()

# グラフのレイアウトを調整
plt.tight_layout()

# グラフの表示
plt.show()
